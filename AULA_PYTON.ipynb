# %% [markdown]
# <a href="https://colab.research.google.com/github/stellatolim12/Pyton/blob/main/AULA_PYTON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**AULA 1** :🇹 🇴 🇾

# %%
print("I competição de programação da Start")
ano = "IX"
print(f"{ano} competição de programação da Start")
# Out:
# I competição de programação da Start
# IX competição de programação da Start

# %% [markdown]
# #**AULA 2**  ☁ 🦩 💞

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
pontos_ana = 2 * livro_ficcao + 5 * livro_infantil
pontos_totais = pontos_rodrigo + pontos_ana
print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")
print(f"Os pontos totais da ana são {pontos_ana}")
print(f"Os pontos totais do Rodrigo e da Ana são {pontos_totais}")
# Out:
# Os pontos totais do Rodrigo são 24
# Os pontos totais do ana são 46
# Os pontos totais do Rodrigo e da Ana são 70

# %% [markdown]
# #**AULA 3 TABUADA**  🍬 🏝 🌺

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} x {contador} = {numero * contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)
# Out:
# Digite um número para ver sua tabuada: 67786
# 67786 x 1 = 67786
# 67786 x 2 = 135572
# 67786 x 3 = 203358
# 67786 x 4 = 271144
# 67786 x 5 = 338930
# 67786 x 6 = 406716
# 67786 x 7 = 474502
# 67786 x 8 = 542288
# 67786 x 9 = 610074
# 67786 x 10 = 677860

# %% [markdown]
# #**AULA 4** ✈ ⚓ ⛈

# %%
peso = float(input("Digite seu peso (em kg): "))
altura = float(input("Digite sua altura (em metros): "))
imc = peso / (altura ** 2)
print(f"\nSeu IMC é: {imc:.2f}")
if imc < 18.5:
    print("Você está abaixo do peso.")
elif 18.5 <= imc < 25:
    print("Você está no peso ideal.")
elif 25 <= imc < 30:
    print("Você está com sobrepeso.")
else:
    print("Você está acima do peso.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3472658501.py in <cell line: 0>()
# ----> 1 peso = float(input("Digite seu peso (em kg): "))
#       2 altura = float(input("Digite sua altura (em metros): "))
#       3 imc = peso / (altura ** 2)
#       4 print(f"\nSeu IMC é: {imc:.2f}")
#       5 if imc < 18.5:
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %% [markdown]
# #**AULA 5** 🎨 🇸 ✨

# %%
print("olá, sou seu assistente virtual, em que posso ajudar?")
nome = input ("Digite seu nome: ")
resposta = input(f"Olá {nome}, qual tema você deseja conversar? Python, Javascript ou Matematica").lower ()
if resposta == "python":
  print(f"Ótimo {nome}, vamos falar sobre Python. \n Você sabia que o Pyrhon foi criado no final da década de 1980, e é uma linguagem de programação de alto nível")
if resposta == "javascript":
  print(f"Ótimo {nome}, vamos falar sobre Javascript. \n Você sabia que foi criada em 1995, e linguagem de programação utilizada para adicionar interatividade e dinamismo a páginas da web, como menus, animações e utilizações de conteúdo em tempo real")
if resposta == "matematica":
  print(f"Ótimo {nome}, vamos falar sobre matematica. \n Voê sabia que é uma estrutura da ciência que estuda quantidades, estruturas, espaços e variações utilizando raciocínios")
else:
  print(f"Que pena {nome}, não sei fala sobre esse assunto.")
# Out:
# olá, sou seu assistente virtual, em que posso ajudar?
# Digite seu nome: gg
# Olá gg, qual tema você deseja conversar? Python, Javascript ou Matematicajavascript
# Ótimo gg, vamos falar sobre Javascript.
#  Você sabia que foi criada em 1995, e linguagem de programação utilizada para adicionar interatividade e dinamismo a páginas da web, como menus, animações e utilizações de conteúdo em tempo real
# Que pena gg, não sei fala sobre esse assunto.

# %% [markdown]
# #**AULA 6** ☕ ⛺ 🛶

# %%
import random
dicas = [
    "Acredite no seu potencial e dê o primeiro passo hoje 💪",
    "Grandes conquistas começam com pequenas atitudes 🌱",
    "Você é mais forte do que imagina 🛡️",
    "O segredo do sucesso é a persistência diária 🔥",
    "Transforme seus sonhos em metas e suas metas em ação. 🎯",
    "Cada desafio é uma oportunidade disfarçada. 🚀"
    "Não espere a motivação chegar — crie você mesmo. ⚡",
    "Sua jornada é única, valorize cada passo. 🌈",
    "O progresso importa mais do que a perfeição. 📈",
    "Quando você acredita, tudo se torna possível. ✨",
]
while True:
  pedido = input("Digite 'dica' para receber uma dica ou 'sair' para encerrar \n ").lower()

  if pedido == "dica":
    dica = random.choice(dicas) # escolhe uma dica aleatória sair
    print(f"Dica: {dica} \n")
    break
  elif pedido == "sair":
    print("Até a próxima! \n")
    break
  else:
    print("Comando inválido. Tente novamente. \n")
    break
